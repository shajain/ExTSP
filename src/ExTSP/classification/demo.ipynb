# %%
from ExTSP.classification.auc_bootstrap import bootstrap_auc_for_disease
from ExTSP.config import Diseases
for disease in ["ASD"]:
    print(f"================{disease}=================")
    for i in range(1,6):
        if disease == "ASD" and i > 3:
            continue
        print(f"Setting {i}")
        result1, summary1 = bootstrap_auc_for_disease(disease, i, n_bootstrap=100, prop_gene_draws=1.0)
        print(f"\tStandard: IsoPath: {summary1['mean_auc_isopath']:.3f}, exTSP: {summary1['mean_auc_extsp']:.3f}")
        if i != 3:
            result2, summary2 = bootstrap_auc_for_disease(disease, i, balanced_negative=True, n_bootstrap=100, prop_gene_draws=1.0)
            print(f"\tBalanced: IsoPath: {summary2['mean_auc_isopath']:.3f}, exTSP: {summary2['mean_auc_extsp']:.3f}")
# Out:
# ================ASD=================
# Setting 1
# 	Standard: IsoPath: 0.529, exTSP: 0.626
# 	Balanced: IsoPath: 0.617, exTSP: 0.673
# Setting 2
# 	Standard: IsoPath: 0.671, exTSP: 0.719
# 	Balanced: IsoPath: 0.670, exTSP: 0.718
# Setting 3
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 9
#       7     continue
#       8 print(f"Setting {i}")
# ----> 9 result1, summary1 = bootstrap_auc_for_disease(disease, i, n_bootstrap=100, prop_gene_draws=1.0)
#      10 print(f"\tStandard: IsoPath: {summary1['mean_auc_isopath']:.3f}, exTSP: {summary1['mean_auc_extsp']:.3f}")
#      11 if i != 3:
#
# File ~/Library/CloudStorage/OneDrive-NortheasternUniversity/Box Sync/code/ExTSP/src/ExTSP/classification/auc_bootstrap.py:334, in bootstrap_auc_for_disease(disease, setting, balanced_negative, n_bootstrap, prop_gene_draws, random_state, use_old_data)
#     332     typeB = "BLB"
#     333 load_triplets = get_tripletSets_with_exTSP_old if use_old_data else get_tripletSets_with_exTSP
# --> 334 df_target_p = load_triplets(disease, type=typeP)
#     335 df_target_b = df_target_p.head(0).copy()
#     336 df_nontarget_p = df_target_p.head(0).copy()
#
# File ~/Library/CloudStorage/OneDrive-NortheasternUniversity/Box Sync/code/ExTSP/src/ExTSP/tripletSets_exTSP.py:20, in get_tripletSets_with_exTSP(disease, type, brainspan, numVars)
#      18 df_vars = pd.read_excel(ExtractedVariants_file, sheet_name=disease)
#      19 if type in ["P", "PLP", "B", "BLB", "VUS"]:
# ---> 20     P_idx, PLP_idx, VUS_idx, BLB_idx, B_idx = clinSig_bool(df_vars["ClinicalSignificance"])
#      21     if type == "P":
#      22         df_vars = df_vars[P_idx]
#
# File ~/Library/CloudStorage/OneDrive-NortheasternUniversity/Box Sync/code/ExTSP/src/ExTSP/commonFunctions.py:29, in clinSig_bool(clinSig, onlyP)
#      28 def clinSig_bool(clinSig, onlyP=False):
# ---> 29     PLP_idx = np.array(['pathogenic' in cs.lower() for cs in clinSig])
#      30     BLB_idx = np.array(['benign' in cs.lower() for cs in clinSig])
#      31     VUS_idx = np.array(['uncertain significance' in cs.lower() for cs in clinSig])
#
# File ~/Library/CloudStorage/OneDrive-NortheasternUniversity/Box Sync/code/ExTSP/src/ExTSP/commonFunctions.py:29, in <listcomp>(.0)
#      28 def clinSig_bool(clinSig, onlyP=False):
# ---> 29     PLP_idx = np.array(['pathogenic' in cs.lower() for cs in clinSig])
#      30     BLB_idx = np.array(['benign' in cs.lower() for cs in clinSig])
#      31     VUS_idx = np.array(['uncertain significance' in cs.lower() for cs in clinSig])
#
# AttributeError: 'float' object has no attribute 'lower'

# %%
from ExTSP.classification.auc_bootstrap import bootstrap_auc_for_disease
result1, summary1 = bootstrap_auc_for_disease("CM", 3, balanced_negative=True, n_bootstrap=1, prop_gene_draws=1.0)

# %%
import numpy as np
tissues = np.array([r.best_tissue for r in result1])
np.unique_counts(tissues)
# Out:
# UniqueCountsResult(values=array(['Heart_Left_Ventricle', 'Muscle_Skeletal', 'Spleen'], dtype='<U20'), counts=array([97,  1,  2]))
